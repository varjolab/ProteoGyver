# %%
import os
import json
import pandas as pd
import json
from components import db_functions
from components.parsing import parse_parameters
parameters = parse_parameters('parameters.json')
rlist = pd.read_excel('combined runlist.xlsx')
db_file = os.path.join('data','db','proteogyver.db')

# %%
from datetime import datetime
def get_mstable_insert(ms_cols, ms_run_datadir, runlist, time_format,runs_done=None,banned_run_dirs = None):
    ms_runs_insert_sql = []
    data_to_enter = []
    failed_json_files = []
    if banned_run_dirs is None:
        banned_run_dirs = [
            'BRE_20_xxxxx_Helsinki',
            'TrapTrouble_3'
        ]
    if runs_done is None:
        runs_done = set()
    for i, datafilename in enumerate(os.listdir(ms_run_datadir)):
        if i % 100 == 0:
            print(i, f'Success: {len(data_to_enter)}, Failed: {len(failed_json_files)}')
        with open(os.path.join(ms_run_datadir, datafilename)) as fil:
            try:
                dat = json.load(fil)
            except json.JSONDecodeError:
                failed_json_files.append(['json decode error', datafilename, ''])
                continue
        if 'polarity_1_sers' in dat:
            del dat['polarity_1_sers']
        if dat['SampleID'] in runs_done: 
            failed_json_files.append(['SampleID in done', datafilename, dat])
            continue
        if dat['SampleInfo'] == ['']:
            failed_json_files.append(['no sample info',datafilename, dat])
            continue
        banned = False
        for b in banned_run_dirs:
            if b in dat['SampleInfo']['SampleTable']['AnalysisHeader']['@FileName']:
                banned = True
        if banned:
            failed_json_files.append(['banned',datafilename, dat])
            continue
        runs_done.add(dat['SampleID'])
        lc_method = None
        ms_method = None
        if isinstance(dat['SampleInfo'], list):
            failed_json_files.append(['no sample info',datafilename, dat])
            continue
        if not 'polarity_1' in dat:
            failed_json_files.append(['no polarity',datafilename, dat])
            continue
        for propdic in dat['SampleInfo']['SampleTable']['SampleTableProperties']['Property']:
            if propdic['@Name'] == 'HyStar_LC_Method_Name':
                lc_method = propdic['@Value']
            if propdic['@Name'] == 'HyStar_MS_Method_Name':
                ms_method = propdic['@Value']
        sample_names = {
            dat['SampleInfo']['SampleTable']['Sample']['@SampleID'],
            dat['SampleInfo']['SampleTable']['Sample']['@SampleID']+'.d',
            dat['SampleInfo']['SampleTable']['Sample']['@DataPath'],
        }
        samplerow = runlist[runlist['Raw file'].isin(sample_names)]
        if (lc_method is None) or (ms_method is None):
            failed_json_files.append(['lc or ms method is none', datafilename, ''])
            continue
        if len([k for k in dat.keys() if 'polarity' in k]) > 1:
            failed_json_files.append(['too much polarity in keys', datafilename, ''])
            continue
        if samplerow.shape[0] == 0:
            samplerow = pd.Series(index = samplerow.columns, data = ['No data' for c in samplerow.columns])
        else:
            samplerow = samplerow.iloc[0]
        instrument = 'TimsTOF 1'
        runtime = datetime.strftime(
            datetime.strptime(
                dat['SampleInfo']['SampleTable']['AnalysisHeader']['@CreationDateTime'].split('+')[0],
                '%Y-%m-%dT%H:%M:%S'
            ),
            time_format
        )    
        samplename = samplerow['Sample name']
        author = samplerow['Who']
        sample_type = samplerow['Sample type']
        bait = samplerow['Bait name']
        bait_uniprot = samplerow['Bait / other uniprot or ID']
        bait_mut = samplerow['Bait mutation']
        cell_line = samplerow['Cell line / material']
        project = samplerow['Project']
        author_notes = samplerow['Notes']
        bait_tag = samplerow['tag']
        try:
            precur = dat['NumPrecursors']
        except KeyError:
            precur = 'No precursor data'
        ms_run_row = [
            dat['SampleID'],
            dat['SampleInfo']['SampleTable']['AnalysisHeader']['@SampleID'],
            samplename,
            dat['SampleInfo']['SampleTable']['AnalysisHeader']['@FileName'],
            runtime,
            runtime.split()[0],
            instrument,
            author,
            sample_type,
            dat['DataType'],
            lc_method,
            ms_method,
            precur,
            bait,
            bait_uniprot,
            bait_mut,
            len(pd.Series(dat['polarity_1']['tic df']['Series'])),
            cell_line,
            project,
            author_notes,
            bait_tag
        ]
        for dataname in ['bpc filtered df', 'tic df', 'bpc unfiltered df']:
            ms_run_row.extend([
                dat['polarity_1'][dataname]['auc'],
                dat['polarity_1'][dataname]['intercepts'],
                dat['polarity_1'][dataname]['peaks_per_timepoint'],
                dat['polarity_1'][dataname]['mean_intensity'],
                dat['polarity_1'][dataname]['max_intensity'],
                json.dumps(dat['polarity_1'][dataname]['Series']),
                dat['polarity_1'][dataname]['trace'],
                json.dumps(dat['polarity_1'][dataname]['intercept_dict']),
            ])   
            for smooth in ['smooth3','smooth6','smooth12','smooth20','smooth30']:
                ms_run_row.append(dat['polarity_1'][dataname][f'trace_{smooth}'])
        
        data_to_enter.append(ms_run_row)
    for data in data_to_enter:
        add_str = f'INSERT INTO ms_runs ({", ".join([c.split()[0] for c in ms_cols])}) VALUES ({", ".join(["?" for _ in ms_cols])})'
        ms_runs_insert_sql.append([add_str, data])
    return (ms_runs_insert_sql, failed_json_files, data_to_enter)

# %%
ms_cols = [
    'run_id TEXT PRIMARY KEY',
    'run_name TEXT NOT NULL',
    'sample_name TEXT NOT NULL',
    'file_name TEXT NOT NULL',
    'run_time TEXT NOT NULL',
    'run_date TEXT NOT NULL',
    'instrument TEXT NOT NULL',
    'author TEXT NOT NULL',
    'sample_type TEXT NOT NULL',
    'run_type TEXT NOT NULL',
    'lc_method TEXT NOT NULL',
    'ms_method TEXT NOT NULL',
    'num_precursors INTEGER NOT NULL',
    'bait TEXT',
    'bait_uniprot TEXT',
    'bait_mutation TEXT',
    'chromatogram_max_time INTEGER NOT NULL',
    'cell_line_or_material TEXT',
    'project TEXT',
    'author_notes TEXT',
    'bait_tag TEXT'
]
keytypes = {
    'auc': 'REAL NOT NULL',
    'intercepts': 'INTEGER NOT NULL',
    'avg_peaks_per_timepoint': 'REAL NOT NULL',
    'mean_intensity': 'INTEGER NOT NULL',
    'max_intensity': 'INTEGER NOT NULL',
    'json': 'TEXT NOT NULL',
    'trace': 'TEXT NOT NULL', 
    'intercept_json': 'TEXT NOT NULL'
}
dfcols = [n[0] for n in ms_cols]
for typ in ['MSn_filtered','TIC','MSn_unfiltered']:
    for key in ['auc','intercepts','avg_peaks_per_timepoint','mean_intensity','max_intensity', 'json','trace', 'intercept_json']:
        ms_cols.append(f'{typ.lower()}_{key.lower()} {keytypes[key]}')
        dfcols.append(f'{typ.lower()}_{key.lower()}')
    for smooth in ['smooth3','smooth6','smooth12','smooth20','smooth30']:
        ms_cols.append(f'{typ.lower()}_trace_{smooth.lower()} {keytypes['trace']}')
        dfcols.append(f'{typ.lower()}_trace_{smooth.lower()}')
rundata_dir = '/media/kmsaloka/Expansion/20241118_parse/ms_runs'
rlist = pd.read_excel('combined runlist.xlsx')
new_dat, new_failed_fils, plain_data = get_mstable_insert(
    ms_cols, 
    rundata_dir,
    rlist,
    parameters['Config']['Time format']
)
# Out:
# 0 Success: 0, Failed: 0
# 100 Success: 100, Failed: 0
# 200 Success: 200, Failed: 0
# 300 Success: 300, Failed: 0
# 400 Success: 400, Failed: 0
# 500 Success: 499, Failed: 1
# 600 Success: 599, Failed: 1
# 700 Success: 699, Failed: 1
# 800 Success: 799, Failed: 1
# 900 Success: 899, Failed: 1
# 1000 Success: 999, Failed: 1
# 1100 Success: 1099, Failed: 1
# 1200 Success: 1199, Failed: 1
# 1300 Success: 1299, Failed: 1
# 1400 Success: 1399, Failed: 1
# 1500 Success: 1499, Failed: 1
# 1600 Success: 1599, Failed: 1
# 1700 Success: 1699, Failed: 1
# 1800 Success: 1799, Failed: 1
# 1900 Success: 1899, Failed: 1
# 2000 Success: 1999, Failed: 1
# 2100 Success: 2099, Failed: 1
# 2200 Success: 2199, Failed: 1
# 2300 Success: 2299, Failed: 1
# 2400 Success: 2399, Failed: 1
# 2500 Success: 2499, Failed: 1
# 2600 Success: 2599, Failed: 1
# 2700 Success: 2699, Failed: 1
# 2800 Success: 2796, Failed: 4
# 2900 Success: 2893, Failed: 7
# 3000 Success: 2993, Failed: 7
# 3100 Success: 3093, Failed: 7
# 3200 Success: 3193, Failed: 7
# 3300 Success: 3293, Failed: 7
# 3400 Success: 3393, Failed: 7
# 3500 Success: 3493, Failed: 7
# 3600 Success: 3593, Failed: 7
# 3700 Success: 3693, Failed: 7
# 3800 Success: 3793, Failed: 7
# 3900 Success: 3893, Failed: 7
# 4000 Success: 3993, Failed: 7
# 4100 Success: 4093, Failed: 7
# 4200 Success: 4193, Failed: 7
# 4300 Success: 4293, Failed: 7
# 4400 Success: 4393, Failed: 7
# 4500 Success: 4493, Failed: 7
# 4600 Success: 4593, Failed: 7
# 4700 Success: 4693, Failed: 7
# 4800 Success: 4793, Failed: 7
# 4900 Success: 4893, Failed: 7
# 5000 Success: 4993, Failed: 7
# 5100 Success: 5093, Failed: 7
# 5200 Success: 5193, Failed: 7
# 5300 Success: 5293, Failed: 7
# 5400 Success: 5393, Failed: 7
# 5500 Success: 5493, Failed: 7
# 5600 Success: 5592, Failed: 8
# 5700 Success: 5692, Failed: 8
# 5800 Success: 5792, Failed: 8
# 5900 Success: 5891, Failed: 9
# 6000 Success: 5991, Failed: 9
# 6100 Success: 6091, Failed: 9
# 6200 Success: 6191, Failed: 9
# 6300 Success: 6291, Failed: 9
# 6400 Success: 6391, Failed: 9
# 6500 Success: 6491, Failed: 9
# 6600 Success: 6591, Failed: 9
# 6700 Success: 6691, Failed: 9
# 6800 Success: 6791, Failed: 9
# 6900 Success: 6891, Failed: 9
# 7000 Success: 6991, Failed: 9
# 7100 Success: 7091, Failed: 9
# 7200 Success: 7191, Failed: 9
# 7300 Success: 7291, Failed: 9
# 7400 Success: 7391, Failed: 9
# 7500 Success: 7491, Failed: 9
# 7600 Success: 7591, Failed: 9
# 7700 Success: 7691, Failed: 9
# 7800 Success: 7791, Failed: 9
# 7900 Success: 7891, Failed: 9
# 8000 Success: 7991, Failed: 9
# 8100 Success: 8091, Failed: 9
# 8200 Success: 8191, Failed: 9
# 8300 Success: 8291, Failed: 9
# 8400 Success: 8391, Failed: 9
# 8500 Success: 8491, Failed: 9
# 8600 Success: 8591, Failed: 9
# 8700 Success: 8691, Failed: 9
# 8800 Success: 8791, Failed: 9
# 8900 Success: 8891, Failed: 9
# 9000 Success: 8991, Failed: 9
# 9100 Success: 9091, Failed: 9
# 9200 Success: 9191, Failed: 9
# 9300 Success: 9291, Failed: 9
# 9400 Success: 9391, Failed: 9
# 9500 Success: 9491, Failed: 9
# 9600 Success: 9591, Failed: 9
# 9700 Success: 9691, Failed: 9
# 9800 Success: 9791, Failed: 9
# 9900 Success: 9891, Failed: 9
# 10000 Success: 9987, Failed: 13
# 10100 Success: 10087, Failed: 13
# 10200 Success: 10187, Failed: 13
# 10300 Success: 10287, Failed: 13
# 10400 Success: 10387, Failed: 13
# 10500 Success: 10487, Failed: 13
# 10600 Success: 10587, Failed: 13
# 10700 Success: 10687, Failed: 13
# 10800 Success: 10787, Failed: 13
# 10900 Success: 10885, Failed: 15
# 11000 Success: 10985, Failed: 15
# 11100 Success: 11085, Failed: 15
# 11200 Success: 11185, Failed: 15
# 11300 Success: 11285, Failed: 15
# 11400 Success: 11385, Failed: 15
# 11500 Success: 11484, Failed: 16
# 11600 Success: 11584, Failed: 16
# 11700 Success: 11684, Failed: 16
# 11800 Success: 11784, Failed: 16
# 11900 Success: 11883, Failed: 17
# 12000 Success: 11982, Failed: 18
# 12100 Success: 12082, Failed: 18
# 12200 Success: 12182, Failed: 18
# 12300 Success: 12282, Failed: 18
# 12400 Success: 12382, Failed: 18
# 12500 Success: 12481, Failed: 19
# 12600 Success: 12579, Failed: 21
# 12700 Success: 12679, Failed: 21
# 12800 Success: 12779, Failed: 21
# 12900 Success: 12878, Failed: 22
# 13000 Success: 12976, Failed: 24
# 13100 Success: 13076, Failed: 24
# 13200 Success: 13176, Failed: 24
# 13300 Success: 13276, Failed: 24
# 13400 Success: 13376, Failed: 24
# 13500 Success: 13474, Failed: 26
# 13600 Success: 13574, Failed: 26
# 13700 Success: 13674, Failed: 26
# 13800 Success: 13774, Failed: 26
# 13900 Success: 13868, Failed: 32
# 14000 Success: 13968, Failed: 32
# 14100 Success: 14068, Failed: 32
# 14200 Success: 14166, Failed: 34
# 14300 Success: 14266, Failed: 34
# 14400 Success: 14366, Failed: 34
# 14500 Success: 14466, Failed: 34
# 14600 Success: 14566, Failed: 34
# 14700 Success: 14666, Failed: 34
# 14800 Success: 14766, Failed: 34
# 14900 Success: 14862, Failed: 38
# 15000 Success: 14950, Failed: 50
# 15100 Success: 15050, Failed: 50
# 15200 Success: 15150, Failed: 50
# 15300 Success: 15250, Failed: 50
# 15400 Success: 15350, Failed: 50
# 15500 Success: 15450, Failed: 50
# 15600 Success: 15550, Failed: 50
# 15700 Success: 15650, Failed: 50
# 15800 Success: 15750, Failed: 50
# 15900 Success: 15850, Failed: 50
# 16000 Success: 15950, Failed: 50
# 16100 Success: 16050, Failed: 50
# 16200 Success: 16150, Failed: 50
# 16300 Success: 16250, Failed: 50
# 16400 Success: 16350, Failed: 50
# 16500 Success: 16450, Failed: 50
# 16600 Success: 16550, Failed: 50
# 16700 Success: 16650, Failed: 50
# 16800 Success: 16750, Failed: 50
# 16900 Success: 16850, Failed: 50
# 17000 Success: 16950, Failed: 50
# 17100 Success: 17050, Failed: 50
# 17200 Success: 17150, Failed: 50
# 17300 Success: 17250, Failed: 50
# 17400 Success: 17350, Failed: 50
# 17500 Success: 17450, Failed: 50
# 17600 Success: 17550, Failed: 50
# 17700 Success: 17650, Failed: 50
# 17800 Success: 17750, Failed: 50
# 17900 Success: 17850, Failed: 50
# 18000 Success: 17949, Failed: 51
# 18100 Success: 18049, Failed: 51
# 18200 Success: 18149, Failed: 51
# 18300 Success: 18249, Failed: 51
# 18400 Success: 18346, Failed: 54
# 18500 Success: 18446, Failed: 54
# 18600 Success: 18546, Failed: 54
# 18700 Success: 18646, Failed: 54
# 18800 Success: 18746, Failed: 54
# 18900 Success: 18846, Failed: 54
# 19000 Success: 18946, Failed: 54
# 19100 Success: 19046, Failed: 54
# 19200 Success: 19146, Failed: 54
# 19300 Success: 19246, Failed: 54
# 19400 Success: 19346, Failed: 54
# 19500 Success: 19446, Failed: 54
# 19600 Success: 19546, Failed: 54
# 19700 Success: 19646, Failed: 54
# 19800 Success: 19746, Failed: 54
# 19900 Success: 19846, Failed: 54
# 20000 Success: 19944, Failed: 56
# 20100 Success: 20044, Failed: 56
# 20200 Success: 20144, Failed: 56
# 20300 Success: 20238, Failed: 62
# 20400 Success: 20335, Failed: 65
# 20500 Success: 20426, Failed: 74
# 20600 Success: 20526, Failed: 74
# 20700 Success: 20626, Failed: 74
# 20800 Success: 20726, Failed: 74
# 20900 Success: 20826, Failed: 74
# 21000 Success: 20926, Failed: 74
# 21100 Success: 21026, Failed: 74

# %%
dfcols = [n.split()[0] for n in ms_cols]
for typ in ['MSn_filtered','TIC','MSn_unfiltered']:
    for key in ['auc','intercepts','avg_peaks_per_timepoint','mean_intensity','max_intensity', 'json','trace', 'intercept_json']:
        if f'{typ.lower()}_{key.lower()}' not in dfcols:
            dfcols.append(f'{typ.lower()}_{key.lower()}')
    for smooth in ['smooth3','smooth6','smooth12','smooth20','smooth30']:
        if f'{typ.lower()}_trace_{smooth.lower()}' not in dfcols:
            dfcols.append(f'{typ.lower()}_trace_{smooth.lower()}')
ndf = pd.DataFrame(columns=dfcols, data=plain_data)

# %%
db_conn = db_functions.create_connection(db_file)
current = db_functions.get_full_table_as_pd(db_conn, 'ms_runs')
db_conn.close()

# %%
modifications = []
additions = []
for index, row in ndf[~ndf.index.isin(current.index)].iterrows():
    additions.append([ms_cols, [index] + [row[c] for c in dfcols[1:]]])
for colname, indexes in differences.items():
    for index in indexes:
        modifications.append([index, colname, ndf.loc[index][colname]])
db_conn = db_functions.create_connection(db_file)
for index, colname, newval in modifications:
    db_functions.modify_record(db_conn, 'ms_runs','run_id',index,[colname],[newval])
for addcols, add_data in additions:
    db_functions.add_record(db_conn, 'ms_runs', addcols, add_data)
db_conn.commit()
db_conn.close()

# %%
db_conn = db_functions.create_connection(db_file)
df = db_functions.get_full_table_as_pd(db_conn, 'known_interactions')
db_conn.close()

# %%
tomap = pd.read_csv(os.path.join('external','SAINTexpress','list.txt'),sep='\t')
df = df[df['uniprot_id_a'].isin(tomap['Prey'])]
df = df[df['uniprot_id_b'].isin(tomap['Prey'])]
tomap2 = {up:gn for up,gn in zip(tomap['Prey'],tomap['PreyGene'])}
gs = [[],[]]
for _, row in df.iterrows():
    gs[0].append(tomap2[row['uniprot_id_a']])
    gs[1].append(tomap2[row['uniprot_id_b']])
df['gene1'] = gs[0]
df['gene2'] = gs[1]
df['interaction2'] = df['uniprot_id_a']+' '+df['uniprot_id_b']
df[['interaction','interaction2']].rename(columns={'interaction': 'GOID','interaction2':'EntrezGeneID'}).to_csv('SAINT_test.tsv',sep='\t',index=False)
df[['interaction','interaction2']].rename(columns={'interaction': 'GOID','interaction2':'EntrezGeneID'}).to_csv('SAINT_test2.tsv',sep=',',index=False)

# %%
df[(df['uniprot_id_a']=='P62736') & (df['uniprot_id_b']=='A5A3E0')]
# Out:
#              interaction uniprot_id_a uniprot_id_b uniprot_id_a_noiso  \
# 1263634  P62736_-_A5A3E0       P62736       A5A3E0             P62736
#
#         uniprot_id_b_noiso source_database isoform_a isoform_b  \
# 1263634             A5A3E0         BIOGRID      None      None
#
#         experimental_role_interactor_a interaction_detection_method  ...  \
# 1263634                           None     Cross-Linking-MS (XL-MS)  ...
#
#         interaction_type experimental_role_interactor_b  \
# 1263634         physical                           None
#
#         annotation_interactor_b biological_role_interactor_a  \
# 1263634                    None                         None
#
#         publication_count                                              notes  \
# 1263634                 1  Experiment throughput from BioGRID: High Throu...
#
#                 update_time   interaction2  gene1  gene2
# 1263634  BioGRID:2024-11-21  P62736 A5A3E0  ACTA2  POTEF
#
# [1 rows x 24 columns]

# %%
df[['interaction','interaction2']]
# Out:
#              interaction   interaction2
# 23       Q99961_-_P50570  Q99961 P50570
# 25       Q99961_-_Q96B97  Q99961 Q96B97
# 27       Q99961_-_Q99961  Q99961 Q99961
# 33       Q99961_-_Q96FW1  Q99961 Q96FW1
# 37       Q99961_-_O14672  Q99961 O14672
# ...                  ...            ...
# 2671770  Q9Y6Y8_-_Q15436  Q9Y6Y8 Q15436
# 2671771  Q9Y6Y8_-_Q15437  Q9Y6Y8 Q15437
# 2671786  Q9Y6Y8_-_Q9Y2G8  Q9Y6Y8 Q9Y2G8
# 2671787  Q9Y6Y8_-_Q9Y547  Q9Y6Y8 Q9Y547
# 2671788  Q9Y6Y8_-_Q9Y5L4  Q9Y6Y8 Q9Y5L4
#
# [372199 rows x 2 columns]

# %%
df[['interaction','uniprot_id_a','uniprot_id_b']]
# Out:
#              interaction uniprot_id_a uniprot_id_b
# 0        O43426_-_Q6ZQ03       O43426       Q6ZQ03
# 1        O43426_-_Q9Z0W5       O43426       Q9Z0W5
# 2        O43426_-_P62994       O43426       P62994
# 3        O43426_-_P17427       O43426       P17427
# 4        O43426_-_P18484       O43426       P18484
# ...                  ...          ...          ...
# 2673547  Q9ZWS9_-_Q9SAZ5       Q9ZWS9       Q9SAZ5
# 2673548  Q9ZWS9_-_Q9ZNV8       Q9ZWS9       Q9ZNV8
# 2673549  Q9ZWS9_-_Q9ZNV9       Q9ZWS9       Q9ZNV9
# 2673550  Q9ZWS9_-_Q9ZVB5       Q9ZWS9       Q9ZVB5
# 2673551  Q9ZWT2_-_Q9M1K3       Q9ZWT2       Q9M1K3
#
# [2673552 rows x 3 columns]

# %%
df
# Out:
#              interaction uniprot_id_a uniprot_id_b uniprot_id_a_noiso  \
# 0        O43426_-_Q6ZQ03       O43426       Q6ZQ03             O43426
# 1        O43426_-_Q9Z0W5       O43426       Q9Z0W5             O43426
# 2        O43426_-_P62994       O43426       P62994             O43426
# 3        O43426_-_P17427       O43426       P17427             O43426
# 4        O43426_-_P18484       O43426       P18484             O43426
# ...                  ...          ...          ...                ...
# 2673547  Q9ZWS9_-_Q9SAZ5       Q9ZWS9       Q9SAZ5             Q9ZWS9
# 2673548  Q9ZWS9_-_Q9ZNV8       Q9ZWS9       Q9ZNV8             Q9ZWS9
# 2673549  Q9ZWS9_-_Q9ZNV9       Q9ZWS9       Q9ZNV9             Q9ZWS9
# 2673550  Q9ZWS9_-_Q9ZVB5       Q9ZWS9       Q9ZVB5             Q9ZWS9
# 2673551  Q9ZWT2_-_Q9M1K3       Q9ZWT2       Q9M1K3             Q9ZWT2
#
#         uniprot_id_b_noiso source_database isoform_a isoform_b  \
# 0                   Q6ZQ03          IntAct      None      None
# 1                   Q9Z0W5          IntAct      None      None
# 2                   P62994          IntAct      None      None
# 3                   P17427          IntAct      None      None
# 4                   P18484          IntAct      None      None
# ...                    ...             ...       ...       ...
# 2673547             Q9SAZ5  IntAct;BIOGRID
# 2673548             Q9ZNV8  IntAct;BIOGRID
# 2673549             Q9ZNV9  IntAct;BIOGRID
# 2673550             Q9ZVB5      IntAct;BAR
# 2673551             Q9M1K3  IntAct;BIOGRID
#
#                         experimental_role_interactor_a  \
# 0        psi-mi:"MI:0496"(bait);psi-mi:"MI:0496"(bait)
# 1        psi-mi:"MI:0496"(bait);psi-mi:"MI:0496"(bait)
# 2        psi-mi:"MI:0496"(bait);psi-mi:"MI:0496"(bait)
# 3                               psi-mi:"MI:0496"(bait)
# 4                               psi-mi:"MI:0496"(bait)
# ...                                                ...
# 2673547  psi-mi:"MI:0498"(prey);psi-mi:"MI:0496"(bait)
# 2673548                         psi-mi:"MI:0496"(bait)
# 2673549  psi-mi:"MI:0498"(prey);psi-mi:"MI:0496"(bait)
# 2673550             psi-mi:"MI:0499"(unspecified role)
# 2673551                         psi-mi:"MI:0498"(prey)
#
#                               interaction_detection_method  ...  \
# 0        psi-mi:"MI:0096"(pull down);psi-mi:"MI:0084"(p...  ...
# 1        psi-mi:"MI:0096"(pull down);psi-mi:"MI:0084"(p...  ...
# 2        psi-mi:"MI:0096"(pull down);psi-mi:"MI:0084"(p...  ...
# 3                              psi-mi:"MI:0096"(pull down)  ...
# 4                              psi-mi:"MI:0096"(pull down)  ...
# ...                                                    ...  ...
# 2673547  psi-mi:"MI:0018"(two hybrid);psi-mi:"MI:0018"(...  ...
# 2673548           psi-mi:"MI:0018"(two hybrid)__Two-hybrid  ...
# 2673549  psi-mi:"MI:0018"(two hybrid);psi-mi:"MI:0018"(...  ...
# 2673550        psi-mi:"MI:2277"(Cr-two hybrid)__Two-hybrid  ...
# 2673551     psi-mi:"MI:0397"(two hybrid array)__Two-hybrid  ...
#
#                               biological_role_interactor_b  \
# 0        psi-mi:"MI:0499"(unspecified role);psi-mi:"MI:...
# 1        psi-mi:"MI:0499"(unspecified role);psi-mi:"MI:...
# 2        psi-mi:"MI:0499"(unspecified role);psi-mi:"MI:...
# 3                       psi-mi:"MI:0499"(unspecified role)
# 4                       psi-mi:"MI:0499"(unspecified role)
# ...                                                    ...
# 2673547  psi-mi:"MI:0499"(unspecified role);psi-mi:"MI:...
# 2673548                 psi-mi:"MI:0499"(unspecified role)
# 2673549  psi-mi:"MI:0499"(unspecified role);psi-mi:"MI:...
# 2673550                 psi-mi:"MI:0499"(unspecified role)
# 2673551                 psi-mi:"MI:0499"(unspecified role)
#
#                                    annotation_interactor_a  \
# 0        comment:"Stoichiometry: 1.0";comment:"Stoichio...
# 1        comment:"Stoichiometry: 1.0";comment:"Stoichio...
# 2        comment:"Stoichiometry: 1.0";comment:"Stoichio...
# 3                             comment:"Stoichiometry: 1.0"
# 4                             comment:"Stoichiometry: 1.0"
# ...                                                    ...
# 2673547
# 2673548
# 2673549
# 2673550
# 2673551
#
#                                 confidence_value  \
# 0        intact-miscore:0.56;intact-miscore:0.56
# 1        intact-miscore:0.56;intact-miscore:0.56
# 2        intact-miscore:0.56;intact-miscore:0.56
# 3                            intact-miscore:0.44
# 4                            intact-miscore:0.40
# ...                                          ...
# 2673547  intact-miscore:0.55;intact-miscore:0.55
# 2673548                      intact-miscore:0.37
# 2673549  intact-miscore:0.55;intact-miscore:0.55
# 2673550                      intact-miscore:0.37
# 2673551                      intact-miscore:0.37
#
#                                           interaction_type  \
# 0        psi-mi:"MI:0407"(direct interaction);psi-mi:"M...
# 1        psi-mi:"MI:0407"(direct interaction);psi-mi:"M...
# 2        psi-mi:"MI:0407"(direct interaction);psi-mi:"M...
# 3                     psi-mi:"MI:0407"(direct interaction)
# 4                   psi-mi:"MI:0915"(physical association)
# ...                                                    ...
# 2673547  psi-mi:"MI:0915"(physical association);psi-mi:...
# 2673548   psi-mi:"MI:0915"(physical association)__physical
# 2673549  psi-mi:"MI:0915"(physical association);psi-mi:...
# 2673550   psi-mi:"MI:0915"(physical association)__physical
# 2673551   psi-mi:"MI:0915"(physical association)__physical
#
#                         experimental_role_interactor_b  \
# 0        psi-mi:"MI:0498"(prey);psi-mi:"MI:0498"(prey)
# 1        psi-mi:"MI:0498"(prey);psi-mi:"MI:0498"(prey)
# 2        psi-mi:"MI:0498"(prey);psi-mi:"MI:0498"(prey)
# 3                               psi-mi:"MI:0498"(prey)
# 4                               psi-mi:"MI:0498"(prey)
# ...                                                ...
# 2673547  psi-mi:"MI:0496"(bait);psi-mi:"MI:0498"(prey)
# 2673548                         psi-mi:"MI:0498"(prey)
# 2673549  psi-mi:"MI:0496"(bait);psi-mi:"MI:0498"(prey)
# 2673550             psi-mi:"MI:0499"(unspecified role)
# 2673551                         psi-mi:"MI:0496"(bait)
#
#                                    annotation_interactor_b  \
# 0        comment:"Stoichiometry: 1.0";comment:"Stoichio...
# 1        comment:"Stoichiometry: 1.0";comment:"Stoichio...
# 2        comment:"Stoichiometry: 1.0";comment:"Stoichio...
# 3                             comment:"Stoichiometry: 1.0"
# 4                             comment:"Stoichiometry: 1.0"
# ...                                                    ...
# 2673547
# 2673548
# 2673549
# 2673550
# 2673551
#
#                               biological_role_interactor_a publication_count  \
# 0        psi-mi:"MI:0499"(unspecified role);psi-mi:"MI:...                 1
# 1        psi-mi:"MI:0499"(unspecified role);psi-mi:"MI:...                 1
# 2        psi-mi:"MI:0499"(unspecified role);psi-mi:"MI:...                 1
# 3                       psi-mi:"MI:0499"(unspecified role)                 1
# 4                       psi-mi:"MI:0499"(unspecified role)                 1
# ...                                                    ...               ...
# 2673547  psi-mi:"MI:0499"(unspecified role);psi-mi:"MI:...                 3
# 2673548                 psi-mi:"MI:0499"(unspecified role)                 2
# 2673549  psi-mi:"MI:0499"(unspecified role);psi-mi:"MI:...                 3
# 2673550                 psi-mi:"MI:0499"(unspecified role)                 1
# 2673551                 psi-mi:"MI:0499"(unspecified role)                 1
#
#                                                      notes  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 2673547  Experiment throughput from BioGRID: High Throu...
# 2673548  Experiment throughput from BioGRID: High Throu...
# 2673549  Experiment throughput from BioGRID: High Throu...
# 2673550  Experiment throughput from BioGRID: High Throu...
# 2673551  Experiment throughput from BioGRID: High Throu...
#
#                                    update_time
# 0                            IntAct:2024-11-21
# 1                            IntAct:2024-11-21
# 2                            IntAct:2024-11-21
# 3                            IntAct:2024-11-21
# 4                            IntAct:2024-11-21
# ...                                        ...
# 2673547  IntAct:2024-11-21__BioGRID:2024-11-21
# 2673548  IntAct:2024-11-21__BioGRID:2024-11-21
# 2673549  IntAct:2024-11-21__BioGRID:2024-11-21
# 2673550  IntAct:2024-11-21__BioGRID:2024-11-21
# 2673551  IntAct:2024-11-21__BioGRID:2024-11-21
#
# [2673552 rows x 21 columns]
